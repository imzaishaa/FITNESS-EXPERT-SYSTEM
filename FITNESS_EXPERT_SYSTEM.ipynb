# %%
# fitness_expert_system.py

class FitnessExpertSystem:
    def __init__(self):
        # Knowledge Base: Exercises categorized by goal, level, and time availability
        self.knowledge_base = {
            'lose_weight': {
                'beginner': {
                    '30 minutes': [
                        {'exercise': 'Jumping Jacks', 'sets': 3, 'reps': '30 seconds', 'rest': '30 seconds'},
                        {'exercise': 'Bodyweight Squats', 'sets': 3, 'reps': 15, 'rest': '30 seconds'},
                        {'exercise': 'Push-Ups', 'sets': 3, 'reps': 10, 'rest': '30 seconds'},
                        {'exercise': 'High Knees', 'sets': 3, 'reps': '30 seconds', 'rest': '30 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Burpees', 'sets': 4, 'reps': 10, 'rest': '30 seconds'},
                        {'exercise': 'Lunges', 'sets': 4, 'reps': 12, 'rest': '30 seconds'},
                        {'exercise': 'Plank', 'sets': 4, 'reps': '45 seconds', 'rest': '30 seconds'},
                        {'exercise': 'Mountain Climbers', 'sets': 4, 'reps': '30 seconds', 'rest': '30 seconds'}
                    ]
                },
                'intermediate': {
                    '30 minutes': [
                        {'exercise': 'Burpees', 'sets': 4, 'reps': 15, 'rest': '30 seconds'},
                        {'exercise': 'Lunges', 'sets': 4, 'reps': 20, 'rest': '30 seconds'},
                        {'exercise': 'Plank', 'sets': 4, 'reps': '1 minute', 'rest': '30 seconds'},
                        {'exercise': 'Mountain Climbers', 'sets': 4, 'reps': '45 seconds', 'rest': '30 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Tuck Jumps', 'sets': 5, 'reps': 15, 'rest': '30 seconds'},
                        {'exercise': 'Plyometric Lunges', 'sets': 5, 'reps':'15 per leg', 'rest': '30 seconds'},
                        {'exercise': 'Handstand Push-Ups', 'sets': 5, 'reps': 10, 'rest': '45 seconds'},
                        {'exercise': 'Kettlebell Swings', 'sets': 5, 'reps': 25, 'rest': '30 seconds'}
                    ]
                }
            },
            'build_muscle': {
                'beginner': {
                    '30 minutes': [
                        {'exercise': 'Dumbbell Bench Press', 'sets': 3, 'reps': 12, 'rest': '60 seconds'},
                        {'exercise': 'Dumbbell Rows', 'sets': 3, 'reps': 12, 'rest': '60 seconds'},
                        {'exercise': 'Bodyweight Squats', 'sets': 3, 'reps': 15, 'rest': '60 seconds'},
                        {'exercise': 'Dumbbell Bicep Curls', 'sets': 3, 'reps': 12, 'rest': '60 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Barbell Squats', 'sets': 4, 'reps': 12, 'rest': '60 seconds'},
                        {'exercise': 'Pull-Ups', 'sets': 4, 'reps': 10, 'rest': '60 seconds'},
                        {'exercise': 'Barbell Bench Press', 'sets': 4, 'reps': 12, 'rest': '60 seconds'},
                        {'exercise': 'Tricep Dips', 'sets': 4, 'reps': 12, 'rest': '60 seconds'}
                    ]
                },
                'intermediate': {
                    '30 minutes': [
                        {'exercise': 'Barbell Bench Press', 'sets': 4, 'reps': 10, 'rest': '60 seconds'},
                        {'exercise': 'Deadlifts', 'sets': 4, 'reps': 10, 'rest': '60 seconds'},
                        {'exercise': 'Barbell Rows', 'sets': 4, 'reps': 12, 'rest': '60 seconds'},
                        {'exercise': 'Tricep Extensions', 'sets': 4, 'reps': 12, 'rest': '60 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Deadlifts', 'sets': 5, 'reps': 8, 'rest': '90 seconds'},
                        {'exercise': 'Bench Press with Chains', 'sets': 5, 'reps': 8, 'rest': '90 seconds'},
                        {'exercise': 'Weighted Pull-Ups', 'sets': 5, 'reps': 8, 'rest': '90 seconds'},
                        {'exercise': 'Barbell Curls', 'sets': 5, 'reps': 10, 'rest': '90 seconds'}
                    ]
                }
            },
            'improve_endurance': {
                'beginner': {
                    '30 minutes': [
                        {'exercise': 'Brisk Walking', 'sets': 1, 'reps': '20 minutes', 'rest': 'None'},
                        {'exercise': 'Jump Rope', 'sets': 3, 'reps': '1 minute', 'rest': '1 minute'}
                    ],
                    '1 hour': [
                        {'exercise': 'Cycling', 'sets': 1, 'reps': '45 minutes', 'rest': 'None'},
                        {'exercise': 'Swimming', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'}
                    ]
                },
                'intermediate': {
                    '30 minutes': [
                        {'exercise': 'Running', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'},
                        {'exercise': 'Rowing', 'sets': 3, 'reps': '5 minutes', 'rest': '2 minutes'}
                    ],
                    '1 hour': [
                        {'exercise': 'Swimming', 'sets': 1, 'reps': '45 minutes', 'rest': 'None'},
                        {'exercise': 'Rowing', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'}
                    ]
                }
            },
            'general_fitness': {
                'beginner': {
                    '30 minutes': [
                        {'exercise': 'Walking', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'},
                        {'exercise': 'Bodyweight Squats', 'sets': 2, 'reps': 15, 'rest': '60 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Jogging', 'sets': 1, 'reps': '40 minutes', 'rest': 'None'},
                        {'exercise': 'Push-Ups', 'sets': 3, 'reps': 15, 'rest': '60 seconds'}
                    ]
                },
                'intermediate': {
                    '30 minutes': [
                        {'exercise': 'Jogging', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'},
                        {'exercise': 'Lunges', 'sets': 3, 'reps': '15 per leg', 'rest': '60 seconds'}
                    ],
                    '1 hour': [
                        {'exercise': 'Running Intervals', 'sets': 1, 'reps': '30 minutes', 'rest': 'None'},
                        {'exercise': 'Burpees', 'sets': 4, 'reps': 20, 'rest': '60 seconds'}
                    ]
                }
            }
        }

    def generate_workout_plan(self, goal, level, time_available):
        try:
            exercises = self.knowledge_base[goal][level][time_available]
        except KeyError:
            return "Invalid input. Please check your goal, level, and time availability."

        plan = f"Workout Plan for {goal.replace('_', ' ').title()} ({level.capitalize()} level) with {time_available}:\n"
        plan += "Each exercise is performed for the specified sets and reps, with rest intervals in between.\n\n"

        for exercise in exercises:
            plan += f"Exercise: {exercise['exercise']}\n"
            plan += f"Sets: {exercise['sets']}\n"
            plan += f"Reps: {exercise['reps']}\n"
            plan += f"Rest: {exercise['rest']}\n\n"

        return plan

    def get_user_input(self):
        print("Welcome to the Fitness Routine Suggestion System!")

        # Get user inputs
        goal = input("Enter your fitness goal (lose_weight, build_muscle, improve_endurance, general_fitness): ").strip().lower()
        level = input("Enter your current fitness level (beginner, intermediate, advanced): ").strip().lower()
        time_available = input("Enter your time available per session (30 minutes, 1 hour): ").strip().lower()

        # Generate and display workout plan
        workout_plan = self.generate_workout_plan(goal, level, time_available)
        print("\n" + workout_plan)

if __name__ == "__main__":
    fitness_expert = FitnessExpertSystem()
    fitness_expert.get_user_input()
# Out:
# Welcome to the Fitness Routine Suggestion System!
# Enter your fitness goal (lose_weight, build_muscle, improve_endurance, general_fitness): lose_weight
